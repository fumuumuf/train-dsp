# %%
import numpy as np
import numpy.matlib as mlb
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import scipy.fftpack as sfft
import cv2
import cis

# %%
G = cv2.imread('/root/book_files/image/building-1081868_960_720.jpg', 0)
plt.imshow(G, cmap='gray')
plt.show()

# %%
print(G.shape)
# 250行目の値をプロット
plt.plot(G[250,:])
plt.show()
# Out:
# (642, 960)

# %%
# 1行の変化をFFT
plt.plot(np.log(np.abs(sfft.fft(G[250,:])))) 
plt.show()

# %% [markdown]
# $\omega$ =0 は平均値
#
# 周波数が小さい部分は建物の形, 高い値は模様やエッジに関係する.
#
# これは, 建物の形を表す信号の変化は緩やかで, 模様は細かく変わるから高い周波数として捉えられるから？
