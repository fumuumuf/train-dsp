# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.matlib as mlb
import cv2
import cis

# %%
cap = cv2.VideoCapture('/root/book_files/movie/636795321.m4v')
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
nFrame = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(nFrame)

# 4次元で時刻順に並べる
frame = np.zeros((height, width, 3, 100), np.uint8)
for k in range(0, frame.shape[3]):
    for i in range(5): # 1frameごとスキップして読み込み
        ret, f = cap.read()
    if not ret:
        break
    frame[:, :, :, k] = f

cis.implay(frame,0.5)
