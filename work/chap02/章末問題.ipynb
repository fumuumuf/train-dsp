# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.matlib as mlb
import cv2
import cis

# %% [markdown]
# ## 問題1

# %%
x = np.zeros((100, 100, 3), dtype=np.uint8)
plt.imshow(x)

# %%
x = np.zeros((100, 100, 3), dtype=np.uint8)
x[:,:,0]=255
plt.imshow(x)

# %% [markdown]
# ## 問題２

# %%
x = np.zeros((100, 100, 3), dtype=np.uint8)
x[:,:,0]=255
plt.imshow(x)

# %%
col = np.zeros((100,100,3),dtype=np.uint8)
# repmatはベクトルだけ
red = mlb.repmat(np.array([255,]),100,100)
col[:,:,0]=red
plt.imshow(col)

# %% [markdown]
# ## 問題３

# %%
white = 255*np.ones((50, 50), dtype=np.uint8)
black = np.zeros((50, 50), dtype=np.uint8)
white.shape

bar = mlb.repmat(np.hstack((white, black)), 1, 3)
bar = np.vstack((bar[:,:250],bar[:,50:]))
bar = mlb.repmat(bar,3,1)
res1 = bar[:250,:250]

plt.imshow(res1,cmap='gray')

# %% [markdown]
# ## 問題4

# %%
res2 = np.zeros((250,250,3),dtype=np.uint8)
bar2 = res1[:250,:250]
res2[:,:,0][res1==255] = 255
res2[:,:,2][res1==0] = 255

plt.imshow(res2)

# %% [markdown]
# ## 問題５

# %%
cyan = [0, 255, 255]
mazenta = [255, 0, 255]

res3 = np.zeros((250, 250, 3), dtype=np.uint8)
res3[:, :][res1 == 255] = cyan
res3[:, :][res1 == 0] = mazenta

plt.imshow(res3)

# %% [markdown]
#  ## 問題７

# %%
image1 = cv2.imread('/root/book_files/image/redpepper.jpg')
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.show()
print(image1.shape)

image2 = cv2.imread('/root/book_files/image/coins-1466263_960_720.jpg')
offset = 150
image2 = image2[:, offset:image1.shape[1]+offset]
image2 = image2[offset:image1.shape[0]+offset]
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.show()
print(image2.shape)
# Out:
# (264, 240, 3)
# (264, 240, 3)

# %%
def mix_image(image1, image2, rate: list):
    i_mixed = image1*rate[0] + image2*rate[1]
    i_mixed = np.where(i_mixed > 255, 255, i_mixed)  # 255以上は255に
    i_mixed = i_mixed.astype(np.uint8)
    plt.imshow(cv2.cvtColor(i_mixed, cv2.COLOR_BGR2RGB))
    plt.show()


mix_image(image1, image2, [0.2, 0.8])
mix_image(image1, image2, [0.5, 0.5])
mix_image(image1, image2, [0.7, 0.3])
